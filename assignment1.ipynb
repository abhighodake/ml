# %%
import pandas as pd

# %%
df23=pd.read_csv("D:\Heart.csv")

# %%
df23.shape   # it is used to knowing the dimenssion or the size of the database
# Out:
# (303, 15)

# %%
df23.columns # it is used to knowing the columns in the database
# Out:
# Index(['Unnamed: 0', 'Age', 'Sex', 'ChestPain', 'RestBP', 'Chol', 'Fbs',
#        'RestECG', 'MaxHR', 'ExAng', 'Oldpeak', 'Slope', 'Ca', 'Thal', 'AHD'],
#       dtype='object')

# %%
df23.head(2)  # it is used to display first two rows with all columns
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
#
#    ExAng  Oldpeak  Slope   Ca    Thal  AHD
# 0      0      2.3      3  0.0   fixed   No
# 1      1      1.5      2  3.0  normal  Yes

# %%
df23.tail(3) # it is used to display last three rows with all columns
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 300      1      1.2      2  1.0  reversable  Yes
# 301      0      0.0      2  1.0      normal  Yes
# 302      0      0.0      1  NaN      normal   No

# %%
df23.info() # it is used to display datatypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  303 non-null    int64
#  1   Age         303 non-null    int64
#  2   Sex         303 non-null    int64
#  3   ChestPain   303 non-null    object
#  4   RestBP      303 non-null    int64
#  5   Chol        303 non-null    int64
#  6   Fbs         303 non-null    int64
#  7   RestECG     303 non-null    int64
#  8   MaxHR       303 non-null    int64
#  9   ExAng       303 non-null    int64
#  10  Oldpeak     303 non-null    float64
#  11  Slope       303 non-null    int64
#  12  Ca          299 non-null    float64
#  13  Thal        301 non-null    object
#  14  AHD         303 non-null    object
# dtypes: float64(2), int64(10), object(3)
# memory usage: 35.6+ KB

# %%
df23.describe()   # it is used to display statistical info
# Out:
#        Unnamed: 0         Age         Sex      RestBP        Chol         Fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   152.000000   54.438944    0.679868  131.689769  246.693069    0.148515
# std     87.612784    9.038662    0.467299   17.599748   51.776918    0.356198
# min      1.000000   29.000000    0.000000   94.000000  126.000000    0.000000
# 25%     76.500000   48.000000    0.000000  120.000000  211.000000    0.000000
# 50%    152.000000   56.000000    1.000000  130.000000  241.000000    0.000000
# 75%    227.500000   61.000000    1.000000  140.000000  275.000000    0.000000
# max    303.000000   77.000000    1.000000  200.000000  564.000000    1.000000
#
#           RestECG       MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# ...

# %%
df23.isna()  # it is used to finding mising values
# Out:
#      Unnamed: 0    Age    Sex  ChestPain  RestBP   Chol    Fbs  RestECG  \
# 0         False  False  False      False   False  False  False    False
# 1         False  False  False      False   False  False  False    False
# 2         False  False  False      False   False  False  False    False
# 3         False  False  False      False   False  False  False    False
# 4         False  False  False      False   False  False  False    False
# ..          ...    ...    ...        ...     ...    ...    ...      ...
# 298       False  False  False      False   False  False  False    False
# 299       False  False  False      False   False  False  False    False
# 300       False  False  False      False   False  False  False    False
# 301       False  False  False      False   False  False  False    False
# 302       False  False  False      False   False  False  False    False
#
#      MaxHR  ExAng  Oldpeak  Slope     Ca   Thal    AHD
# ...

# %%
df23.isna().sum()  # it is used to count and the sum of missing values
# Out:
# Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            4
# Thal          2
# AHD           0
# dtype: int64

# %% [markdown]
# df23.==0

# %%
df23==0
# Out:
#      Unnamed: 0    Age    Sex  ChestPain  RestBP   Chol    Fbs  RestECG  \
# 0         False  False  False      False   False  False  False    False
# 1         False  False  False      False   False  False   True    False
# 2         False  False  False      False   False  False   True    False
# 3         False  False  False      False   False  False   True     True
# 4         False  False   True      False   False  False   True    False
# ..          ...    ...    ...        ...     ...    ...    ...      ...
# 298       False  False  False      False   False  False   True     True
# 299       False  False  False      False   False  False  False     True
# 300       False  False  False      False   False  False   True     True
# 301       False  False   True      False   False  False   True    False
# 302       False  False  False      False   False  False   True     True
#
#      MaxHR  ExAng  Oldpeak  Slope     Ca   Thal    AHD
# ...

# %%
df23['Age']  # it is used to display specific column
# Out:
# 0      63
# 1      67
# 2      67
# 3      37
# 4      41
#        ..
# 298    45
# 299    68
# 300    57
# 301    57
# 302    38
# Name: Age, Length: 303, dtype: int64

# %%
df23['Age'].mean()  # it is used to calculate mean of a particular column
# Out:
# 54.43894389438944

# %%
df23['Age'].max() # it is used to calculate the maximum value of the particular column Also we can calculate avg,min value by using same syntax
# Out:
# 77

# %%
df23.loc[:,'Age']  # this is used to extract only that info which we need  # : it is used for all values first is for row and second is for column
# Out:
# 0      63
# 1      67
# 2      67
# 3      37
# 4      41
#        ..
# 298    45
# 299    68
# 300    57
# 301    57
# 302    38
# Name: Age, Length: 303, dtype: int64

# %%
df23.loc[:,:]  # it display all the info
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df23.iloc[:,:]  # iloc is used for display info by using row or column numbers
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df23.iloc[1,1]
# Out:
# 67

# %%
df23.loc[:,['Age','ChestPain','Sex']]  # it is used for diplay all rows with specific columns
# Out:
#      Age     ChestPain  Sex
# 0     63       typical    1
# 1     67  asymptomatic    1
# 2     67  asymptomatic    1
# 3     37    nonanginal    1
# 4     41    nontypical    0
# ..   ...           ...  ...
# 298   45       typical    1
# 299   68  asymptomatic    1
# 300   57  asymptomatic    1
# 301   57    nontypical    0
# 302   38    nonanginal    1
#
# [303 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split     # it is used to import library to split the dara for train or test the data

# %%
x=df23.iloc[:,:-1]    # by this we are declaring a variables x and y
y=df23.iloc[:,:-1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)   # by this we are split the data for 30% to test and 70% to train

# %%
print(x_train)
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 292         293   44    1  asymptomatic     120   169    0        0    144
# 136         137   70    1  asymptomatic     145   174    0        0    125
# 45           46   58    1    nonanginal     112   230    0        2    165
# 96           97   59    1  asymptomatic     110   239    0        2    142
# 238         239   49    0    nontypical     134   271    0        0    162
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 237         238   46    1  asymptomatic     120   249    0        2    144
# 24           25   60    1  asymptomatic     130   206    0        2    132
# 23           24   58    1    nonanginal     132   224    0        2    173
# 48           49   65    0    nonanginal     140   417    1        2    157
# 222         223   39    0    nonanginal      94   199    0        0    179
#
#      ExAng  Oldpeak  Slope   Ca        Thal
# ...

# %%
print(x_test)
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 228         229   54    1  asymptomatic     110   206    0        2    108
# 65           66   60    1  asymptomatic     145   282    0        2    142
# 78           79   48    1    nontypical     130   245    0        2    180
# 33           34   59    1  asymptomatic     135   234    0        0    161
# 51           52   65    1  asymptomatic     120   177    0        0    140
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 113         114   43    0  asymptomatic     132   341    1        2    136
# 36           37   43    1  asymptomatic     120   177    0        2    120
# 85           86   44    1    nonanginal     140   235    0        2    180
# 131         132   51    1    nonanginal      94   227    0        0    154
# 25           26   50    0    nonanginal     120   219    0        0    158
#
#      ExAng  Oldpeak  Slope   Ca        Thal
# ...

# %%
print(y_train)
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 292         293   44    1  asymptomatic     120   169    0        0    144
# 136         137   70    1  asymptomatic     145   174    0        0    125
# 45           46   58    1    nonanginal     112   230    0        2    165
# 96           97   59    1  asymptomatic     110   239    0        2    142
# 238         239   49    0    nontypical     134   271    0        0    162
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 237         238   46    1  asymptomatic     120   249    0        2    144
# 24           25   60    1  asymptomatic     130   206    0        2    132
# 23           24   58    1    nonanginal     132   224    0        2    173
# 48           49   65    0    nonanginal     140   417    1        2    157
# 222         223   39    0    nonanginal      94   199    0        0    179
#
#      ExAng  Oldpeak  Slope   Ca        Thal
# ...

# %%
print(y_test)
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 228         229   54    1  asymptomatic     110   206    0        2    108
# 65           66   60    1  asymptomatic     145   282    0        2    142
# 78           79   48    1    nontypical     130   245    0        2    180
# 33           34   59    1  asymptomatic     135   234    0        0    161
# 51           52   65    1  asymptomatic     120   177    0        0    140
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 113         114   43    0  asymptomatic     132   341    1        2    136
# 36           37   43    1  asymptomatic     120   177    0        2    120
# 85           86   44    1    nonanginal     140   235    0        2    180
# 131         132   51    1    nonanginal      94   227    0        0    154
# 25           26   50    0    nonanginal     120   219    0        0    158
#
#      ExAng  Oldpeak  Slope   Ca        Thal
# ...

# %%
import numpy as np

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,accuracy_score, classification_report,precision_score,recall_score,f1_score

# %%
actual = np.array([1,1,0,0,1,0])    # using numpy array we stored actual and predict values
predicated= np.array([1,0,0,0,1,1])

# %%
confusion_metrix =confusion_matrix(actual, predicated)  # this command is used to create confusion matrix

# %%
print(confusion_metrix)   # this is used to print confusion matrix
# Out:
# [[2 1]
#  [1 2]]

# %%
cm_display=ConfusionMatrixDisplay(confusion_metrix, display_labels=[0,1])
cm_display.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [48], in <cell line: 3>()
#       1 cm_display=ConfusionMatrixDisplay(confusion_metrix, display_labels=[0,1])
#       2 cm_display.plot()
# ----> 3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
print("Precision = {:0.2f}".format(precision_score(actual,predicated)))
# Out:
# Precision = 0.67

# %%
print("Recall= {0:0.2f}".format(recall_score(actual,predicated)))
# Out:
# Recall= 0.67

# %%
print("f1_score= {:0.2f}".format(f1_score(actual,predicated)))
# Out:
# f1_score= 0.67

# %%
print("classsification Report= {}".
format(classification_report(actual,predicated)))
# Out:
# classsification Report=               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67         3
#            1       0.67      0.67      0.67         3
#
#     accuracy                           0.67         6
#    macro avg       0.67      0.67      0.67         6
# weighted avg       0.67      0.67      0.67         6
